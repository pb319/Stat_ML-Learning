# %%
import pandas as pd

# %%
df= pd.read_csv("/home/prasun/GitDemo/Stat_ML-Learning/Exercise7/data.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.promotion_last_5years.unique()
# Out:
# array([0, 1])

# %%
df.Work_accident.unique()
# Out:
# array([0, 1])

# %%
ls =[]
for i in df:
    ls.append(i)
for i in ls:
    print(f"{i} has {df[i].unique()}")
# Out:
# satisfaction_level has [0.38 0.8  0.11 0.72 0.37 0.41 0.1  0.92 0.89 0.42 0.45 0.84 0.36 0.78
#  0.76 0.09 0.46 0.4  0.82 0.87 0.57 0.43 0.13 0.44 0.39 0.85 0.81 0.9
#  0.74 0.79 0.17 0.24 0.91 0.71 0.86 0.14 0.75 0.7  0.31 0.73 0.83 0.32
#  0.54 0.27 0.77 0.88 0.48 0.19 0.6  0.12 0.61 0.33 0.56 0.47 0.28 0.55
#  0.53 0.59 0.66 0.25 0.34 0.58 0.51 0.35 0.64 0.5  0.23 0.15 0.49 0.3
#  0.63 0.21 0.62 0.29 0.2  0.16 0.65 0.68 0.67 0.22 0.26 0.99 0.98 1.
#  0.52 0.93 0.97 0.69 0.94 0.96 0.18 0.95]
# last_evaluation has [0.53 0.86 0.88 0.87 0.52 0.5  0.77 0.85 1.   0.54 0.81 0.92 0.55 0.56
#  0.47 0.99 0.51 0.89 0.83 0.95 0.57 0.49 0.46 0.62 0.94 0.48 0.8  0.74
#  0.7  0.78 0.91 0.93 0.98 0.97 0.79 0.59 0.84 0.45 0.96 0.68 0.82 0.9
#  0.71 0.6  0.65 0.58 0.72 0.67 0.75 0.73 0.63 0.61 0.76 0.66 0.69 0.37
#  0.64 0.39 0.41 0.43 0.44 0.36 0.38 0.4  0.42]
# number_project has [2 5 7 6 4 3]
# average_montly_hours has [157 262 272 223 159 153 247 259 224 142 135 305 234 148 137 143 160 255
#  282 147 304 139 158 242 239 128 132 294 134 145 140 246 126 306 152 269
#  127 281 276 182 273 307 309 225 226 308 244 286 161 264 277 275 149 295
#  151 249 291 232 130 129 155 265 279 284 221 154 150 267 257 177 144 289
#  258 263 251 133 216 300 138 260 183 250 292 283 245 256 278 240 136 301
#  243 296 274 164 146 261 285 141 297 156 287 219 254 228 131 252 236 270
#  298 192 248 266 238 229 233 268 231 253 302 271 290 235 293 241 218 199
#  180 195 237 227 172 206 181 217 310 214 198 211 222 213 202 184 204 288
#  220 299 303 212 196 179 205 230 203 280 169 188 178 175 166 163 168 165
#  189 162 215 193 176 191 174 201 208 171 111 104 106 100 194 209 185 200
#  207 187 210 186 167 108 122 110 115 197 102 109 190  99 101  97 173 121
#  170 105 118 119 117 114  96  98 107 123 116 125 113 120 112 124 103]
# time_spend_company has [ 3  6  4  5  2  8 10  7]
# Work_accident has [0 1]
# left has [1 0]
# promotion_last_5years has [0 1]
# Department has ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# salary has ['low' 'medium' 'high']

# %% [markdown]
# Hence we can easily see fields like `Work_accident`, `left`, `promotion_last_5years` is categorical columns(binary)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[ls],figsize= (20,18), marker= "+", alpha= 1)
# Out:
# /home/prasun/python_workspace/penv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/misc.py:96: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# array([[<Axes: xlabel='satisfaction_level', ylabel='satisfaction_level'>,
#         <Axes: xlabel='last_evaluation', ylabel='satisfaction_level'>,
#         <Axes: xlabel='number_project', ylabel='satisfaction_level'>,
#         <Axes: xlabel='average_montly_hours', ylabel='satisfaction_level'>,
#         <Axes: xlabel='time_spend_company', ylabel='satisfaction_level'>,
#         <Axes: xlabel='Work_accident', ylabel='satisfaction_level'>,
#         <Axes: xlabel='left', ylabel='satisfaction_level'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='satisfaction_level'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='last_evaluation'>,
#         <Axes: xlabel='last_evaluation', ylabel='last_evaluation'>,
#         <Axes: xlabel='number_project', ylabel='last_evaluation'>,
#         <Axes: xlabel='average_montly_hours', ylabel='last_evaluation'>,
#         <Axes: xlabel='time_spend_company', ylabel='last_evaluation'>,
#         <Axes: xlabel='Work_accident', ylabel='last_evaluation'>,
#         <Axes: xlabel='left', ylabel='last_evaluation'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='last_evaluation'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='number_project'>,
#         <Axes: xlabel='last_evaluation', ylabel='number_project'>,
#         <Axes: xlabel='number_project', ylabel='number_project'>,
#         <Axes: xlabel='average_montly_hours', ylabel='number_project'>,
#         <Axes: xlabel='time_spend_company', ylabel='number_project'>,
#         <Axes: xlabel='Work_accident', ylabel='number_project'>,
#         <Axes: xlabel='left', ylabel='number_project'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='number_project'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='average_montly_hours'>,
#         <Axes: xlabel='last_evaluation', ylabel='average_montly_hours'>,
#         <Axes: xlabel='number_project', ylabel='average_montly_hours'>,
#         <Axes: xlabel='average_montly_hours', ylabel='average_montly_hours'>,
#         <Axes: xlabel='time_spend_company', ylabel='average_montly_hours'>,
#         <Axes: xlabel='Work_accident', ylabel='average_montly_hours'>,
#         <Axes: xlabel='left', ylabel='average_montly_hours'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='average_montly_hours'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='time_spend_company'>,
#         <Axes: xlabel='last_evaluation', ylabel='time_spend_company'>,
#         <Axes: xlabel='number_project', ylabel='time_spend_company'>,
#         <Axes: xlabel='average_montly_hours', ylabel='time_spend_company'>,
#         <Axes: xlabel='time_spend_company', ylabel='time_spend_company'>,
#         <Axes: xlabel='Work_accident', ylabel='time_spend_company'>,
#         <Axes: xlabel='left', ylabel='time_spend_company'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='time_spend_company'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='Work_accident'>,
#         <Axes: xlabel='last_evaluation', ylabel='Work_accident'>,
#         <Axes: xlabel='number_project', ylabel='Work_accident'>,
#         <Axes: xlabel='average_montly_hours', ylabel='Work_accident'>,
#         <Axes: xlabel='time_spend_company', ylabel='Work_accident'>,
#         <Axes: xlabel='Work_accident', ylabel='Work_accident'>,
#         <Axes: xlabel='left', ylabel='Work_accident'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='Work_accident'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='left'>,
#         <Axes: xlabel='last_evaluation', ylabel='left'>,
#         <Axes: xlabel='number_project', ylabel='left'>,
#         <Axes: xlabel='average_montly_hours', ylabel='left'>,
#         <Axes: xlabel='time_spend_company', ylabel='left'>,
#         <Axes: xlabel='Work_accident', ylabel='left'>,
#         <Axes: xlabel='left', ylabel='left'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='left'>],
#        [<Axes: xlabel='satisfaction_level', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='last_evaluation', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='number_project', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='average_montly_hours', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='time_spend_company', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='Work_accident', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='left', ylabel='promotion_last_5years'>,
#         <Axes: xlabel='promotion_last_5years', ylabel='promotion_last_5years'>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
plt.xlabel('left')
plt.xlabel('satisfaction_level')
plt.scatter(df['satisfaction_level'],df['left'])

# %%
# Suppress Warning for Clean Notebook
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
df = pd.read_csv("/home/prasun/GitDemo/Stat_ML-Learning/Exercise16/practicedata.csv")
df.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
#        'CouncilArea'],
#       dtype='object')

# %%
df["Price"] = df.Price.fillna(df.Price.mean())
df.info()
df[['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
       'Date', 'Postcode', 'Regionname', 'Propertycount', 'Distance',
       'CouncilArea']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63023 entries, 0 to 63022
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         63023 non-null  object
#  1   Address        63023 non-null  object
#  2   Rooms          63023 non-null  int64
#  3   Type           63023 non-null  object
#  4   Price          63023 non-null  float64
#  5   Method         63023 non-null  object
#  6   SellerG        63023 non-null  object
#  7   Date           63023 non-null  object
#  8   Postcode       63023 non-null  int64
#  9   Regionname     63023 non-null  object
#  10  Propertycount  63023 non-null  int64
#  11  Distance       63023 non-null  float64
#  12  CouncilArea    63023 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 6.3+ MB
#                  Suburb           Address  Rooms Type         Price Method  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63023 entries, 0 to 63022
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         63023 non-null  object
#  1   Address        63023 non-null  object
#  2   Rooms          63023 non-null  int64
#  3   Type           63023 non-null  object
#  4   Price          63023 non-null  float64
#  5   Method         63023 non-null  object
#  6   SellerG        63023 non-null  object
#  7   Date           63023 non-null  object
#  8   Postcode       63023 non-null  int64
#  9   Regionname     63023 non-null  object
#  10  Propertycount  63023 non-null  int64
#  11  Distance       63023 non-null  float64
#  12  CouncilArea    63023 non-null  object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 6.3+ MB

# %%
h = df[["Rooms","Price","Propertycount","Distance"]].corr().round(2)

# %%
from pandas.plotting import scatter_matrix
att =["Rooms","Price","Propertycount","Distance","CouncilArea"]
scatter_matrix(df[att],figsize= (20,16))
# Out:
# array([[<Axes: xlabel='Rooms', ylabel='Rooms'>,
#         <Axes: xlabel='Price', ylabel='Rooms'>,
#         <Axes: xlabel='Propertycount', ylabel='Rooms'>,
#         <Axes: xlabel='Distance', ylabel='Rooms'>],
#        [<Axes: xlabel='Rooms', ylabel='Price'>,
#         <Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Propertycount', ylabel='Price'>,
#         <Axes: xlabel='Distance', ylabel='Price'>],
#        [<Axes: xlabel='Rooms', ylabel='Propertycount'>,
#         <Axes: xlabel='Price', ylabel='Propertycount'>,
#         <Axes: xlabel='Propertycount', ylabel='Propertycount'>,
#         <Axes: xlabel='Distance', ylabel='Propertycount'>],
#        [<Axes: xlabel='Rooms', ylabel='Distance'>,
#         <Axes: xlabel='Price', ylabel='Distance'>,
#         <Axes: xlabel='Propertycount', ylabel='Distance'>,
#         <Axes: xlabel='Distance', ylabel='Distance'>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(h, annot= True, )
# Out:
# <Axes: >

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
rd = Ridge(alpha= 50, max_iter= 100 , tol=0.1)
ls = Lasso(alpha= 50, max_iter= 100 , tol=0.1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[["Rooms","Distance"]],df[["Price"]],test_size= 0.3)
rd.fit(X_train,y_train)
ls.fit(X_train,y_train)
rd.score(X_test,y_test)
ls.score(X_test,y_test)
# Out:
# 0.2450232844086243

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/home/prasun/GitDemo/Stat_ML-Learning/Exercise6/data.csv")
df.head()
# Out:
#    Mileage  Sell Price($)  Age(yrs)
# 0    69000          18000         6
# 1    35000          34000         3
# 2    57000          26100         5
# 3    22500          40000         2
# 4    46000          31500         4

# %%
# %matplotlib inline
plt.xlabel("Mileage")
plt.xlabel("Sell Price($)")
plt.scatter(df["Mileage"],df["Sell Price($)"])

# %%
# %matplotlib inline
plt.xlabel("Age(yrs)")
plt.xlabel("Sell Price($)")
plt.scatter(df["Age(yrs)"],df["Sell Price($)"])

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['Mileage','Sell Price($)','Age(yrs)']],figsize= (16,12), marker= "+", alpha= 1)
# Out:
# /home/prasun/python_workspace/penv/lib/python3.11/site-packages/pandas/plotting/_matplotlib/misc.py:96: UserWarning: You passed a edgecolor/edgecolors ('none') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# array([[<Axes: xlabel='Mileage', ylabel='Mileage'>,
#         <Axes: xlabel='Sell Price($)', ylabel='Mileage'>,
#         <Axes: xlabel='Age(yrs)', ylabel='Mileage'>],
#        [<Axes: xlabel='Mileage', ylabel='Sell Price($)'>,
#         <Axes: xlabel='Sell Price($)', ylabel='Sell Price($)'>,
#         <Axes: xlabel='Age(yrs)', ylabel='Sell Price($)'>],
#        [<Axes: xlabel='Mileage', ylabel='Age(yrs)'>,
#         <Axes: xlabel='Sell Price($)', ylabel='Age(yrs)'>,
#         <Axes: xlabel='Age(yrs)', ylabel='Age(yrs)'>]], dtype=object)

# %%
X = df.drop(['Sell Price($)'],axis= "columns")
y = df['Sell Price($)']
# Out:
# 13

# %%
# Splitting the data
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size= 0.25) #random_state = 10

# %%
reg =LinearRegression()
reg.fit(X_train,y_train)
reg.predict(X_test)
# Out:
# array([40618.48583372, 16119.36832327, 28233.62749652, 24917.13887599])

# %%
reg.score(X_test,y_test)
# Out:
# 0.9247569982621359
